# %%
from datetime import datetime,date
import matplotlib.pyplot as plt
import numpy as np
import sklearn.linear_model
import sklearn.model_selection
import pandas as pd
import yfinance as yfin
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 7
#       5 import sklearn.model_selection
#       6 import pandas as pd
# ----> 7 import yfinance as yfin
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
start=datetime(2022,1,5)
end=datetime.today()
df_aapl=yfin.download("AAPL",start,end)
df_fb=yfin.download("META",start,end)
df_gold=yfin.download("GLD",start,end)
df_aapl.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 start=datetime(2022,1,5)
#       2 end=datetime.today()
# ----> 3 df_aapl=yfin.download("AAPL",start,end)
#       4 df_fb=yfin.download("META",start,end)
#       5 df_gold=yfin.download("GLD",start,end)
#
# NameError: name 'yfin' is not defined

# %%
df_aapl['SMA']=df_aapl['Close'].rolling(window=14).mean()
df_aapl['SMA50']=df_aapl['Close'].rolling(window=50).mean()
df_aapl['Close'].plot( figsize=(15.6),color="orange")
df_aapl['SMA'].plot(figsize=(15.6),color="blue")
df_aapl['SMA50'].plot(figsize=(15.6),color='green')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_aapl['SMA']=df_aapl['Close'].rolling(window=14).mean()
#       2 df_aapl['SMA50']=df_aapl['Close'].rolling(window=50).mean()
#       3 df_aapl['Close'].plot( figsize=(15.6),color="orange")
#
# NameError: name 'df_aapl' is not defined

# %%
df_aapl['change']=(((df_appl['Close']-df_aapl['Open']))/(df_aapl['Open'])*100)
df_fb['change']=(((df_fb['Close']-df_fb['Open']))/(df_fb['Open'])*100)
df_gold['change']=(((df_gold['Close']-df_gold['Open'])) / (df_gold['Open'])*100)

df_aapl.tail(5).round(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_aapl['change']=(((df_appl['Close']-df_aapl['Open']))/(df_aapl['Open'])*100)
#       2 df_fb['change']=(((df_fb['Close']-df_fb['Open']))/(df_fb['Open'])*100)
#       3 df_gold['change']=(((df_gold['Close']-df_gold['Open'])) / (df_gold['Open'])*100)
#
# NameError: name 'df_appl' is not defined

# %%
df_aapl['Close'].plot(figsize=(15,6),color="red")
df_fb['Close'].plot(figsize=(15,6),color="blue")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_aapl['Close'].plot(figsize=(15,6),color="red")
#       2 df_fb['Close'].plot(figsize=(15,6),color="blue")
#       3 plt.show()
#
# NameError: name 'df_aapl' is not defined
